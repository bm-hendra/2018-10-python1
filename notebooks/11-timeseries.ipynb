# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2018, 10, 19, 13, 7, 55, 164939)

# %%
t1 = datetime.now()

# %%
t2 = datetime(1970, 1, 1)

# %%
diff = t1 - t2

# %%
diff
# Out:
# datetime.timedelta(days=17823, seconds=47348, microseconds=700180)

# %%
type(diff)
# Out:
# datetime.timedelta

# %%
type(t2)
# Out:
# datetime.datetime

# %%
import pandas as pd

# %%
ebola = pd.read_csv('../data/country_timeseries.csv')

# %%
ebola.iloc[:5, :5]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.2+ KB

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'])

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# date_dt                122 non-null datetime64[ns]
# ...

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'], format='%m/%d/%Y')

# %%
# https://docs.python.org/3.7/library/datetime.html

# %%
ebola = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null datetime64[ns]
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# ...

# %%
d = pd.to_datetime('2018-10-19')

# %%
d.year
# Out:
# 2018

# %%
d.month
# Out:
# 10

# %%
d.day
# Out:
# 19

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'])

# %%
ebola['year'] = ebola['date_dt'].dt.year

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 20 columns):
# Date                   122 non-null datetime64[ns]
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# date_dt                122 non-null datetime64[ns]
# ...

# %%
ebola['date_dt'].min()
# Out:
# Timestamp('2014-03-22 00:00:00')

# %%
ebola['date_dt'].max()
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
ebola['outbreak_d'] = ebola['date_dt'] - ebola['date_dt'].min()

# %%
ebola['outbreak_d'].head()
# Out:
# 0   289 days
# 1   288 days
# 2   287 days
# 3   286 days
# 4   284 days
# Name: outbreak_d, dtype: timedelta64[ns]

# %%
banks = pd.read_csv('../data/banklist.csv',
                    parse_dates=['Closing Date', 'Updated Date'])

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 7 columns):
# Bank Name                553 non-null object
# City                     553 non-null object
# ST                       553 non-null object
# CERT                     553 non-null int64
# Acquiring Institution    553 non-null object
# Closing Date             553 non-null datetime64[ns]
# Updated Date             553 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.3+ KB

# %%
banks['closing_quarter'], banks['closing_year'] = (banks['Closing Date'].dt.quarter,
                                                  banks['Closing Date'].dt.year)

# %%
banks.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date  \
# 0   1802            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 1  30003  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 2  58302                         Whitney Bank   2017-04-28   2017-07-26
# 3  35495                    Cache Valley Bank   2017-03-03   2017-05-18
# 4  19328                  State Bank of Texas   2017-01-27   2017-05-18
#
#    closing_quarter  closing_year
# 0                2          2017
# ...

# %%
banks.groupby(['closing_year']).size()
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      6
# dtype: int64

# %%
banks.groupby(['closing_year', 'closing_quarter']).size()
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax = banks.groupby(['closing_year']).size().plot()
plt.show()

# %%
fig, ax = plt.subplots()
ax = banks.groupby(['closing_year', 'closing_quarter']).size().plot()
plt.show()

# %%
tesla = pd.read_csv('../data/tesla_stock_yahoo.csv', parse_dates=[0])
tesla.head()
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla.loc[(tesla['Date'].dt.year == 2010) & (tesla['Date'].dt.month == 6)]
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100

# %%
tesla.index = tesla['Date']

# %%
tesla.head()
# Out:
#                  Date       Open   High        Low      Close  Adj Close  \
# Date
# 2010-06-29 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999
# 2010-06-30 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000
# 2010-07-01 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999
# 2010-07-02 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001
# 2010-07-06 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001
#
#               Volume
# Date
# 2010-06-29  18766300
# 2010-06-30  17187100
# 2010-07-01   8218800
# 2010-07-02   5139800
# 2010-07-06   6866900

# %%
tesla['2015']
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2015-01-02 2015-01-02  222.869995  223.250000  213.259995  219.309998
# 2015-01-05 2015-01-05  214.550003  216.500000  207.160004  210.089996
# 2015-01-06 2015-01-06  210.059998  214.199997  204.210007  211.279999
# 2015-01-07 2015-01-07  213.350006  214.779999  209.779999  210.949997
# 2015-01-08 2015-01-08  212.809998  213.800003  210.009995  210.619995
# 2015-01-09 2015-01-09  208.919998  209.979996  204.960007  206.660004
# 2015-01-12 2015-01-12  203.050003  204.470001  199.250000  202.210007
# 2015-01-13 2015-01-13  203.320007  207.610001  200.910004  204.250000
# 2015-01-14 2015-01-14  185.830002  195.199997  185.000000  192.690002
# 2015-01-15 2015-01-15  194.490005  195.750000  190.000000  191.869995
# 2015-01-16 2015-01-16  190.699997  194.490005  189.649994  193.070007
# 2015-01-20 2015-01-20  193.869995  194.119995  187.039993  191.929993
# ...

# %%
ebola.head()
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#       ...      Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
pd.date_range(start='2014-12-31', end='2015-01-5', freq='B')
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-05'], dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start='2014-12-31', end='2015-01-5', freq='2B')
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-02'], dtype='datetime64[ns]', freq='2B')

# %%
pd.date_range(start='2017-01-01', end='2017-12-31', freq='WOM-1THU')
# Out:
# DatetimeIndex(['2017-01-05', '2017-02-02', '2017-03-02', '2017-04-06',
#                '2017-05-04', '2017-06-01', '2017-07-06', '2017-08-03',
#                '2017-09-07', '2017-10-05', '2017-11-02', '2017-12-07'],
#               dtype='datetime64[ns]', freq='WOM-1THU')

# %%
pd.date_range(start='2017-01-01', end='2017-12-31', freq='WOM-3FRI')
# Out:
# DatetimeIndex(['2017-01-20', '2017-02-17', '2017-03-17', '2017-04-21',
#                '2017-05-19', '2017-06-16', '2017-07-21', '2017-08-18',
#                '2017-09-15', '2017-10-20', '2017-11-17', '2017-12-15'],
#               dtype='datetime64[ns]', freq='WOM-3FRI')

# %%
tesla.head()
# Out:
#                  Date       Open   High        Low      Close  Adj Close  \
# Date
# 2010-06-29 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999
# 2010-06-30 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000
# 2010-07-01 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999
# 2010-07-02 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001
# 2010-07-06 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001
#
#               Volume
# Date
# 2010-06-29  18766300
# 2010-06-30  17187100
# 2010-07-01   8218800
# 2010-07-02   5139800
# 2010-07-06   6866900

# %%
down = tesla.resample('M').mean()
down.head()
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2010-06-30  22.395001  27.710000  20.420000  23.860000  23.860000
# 2010-07-31  20.073334  20.640000  18.816190  19.558095  19.558095
# 2010-08-31  19.545455  19.910000  19.080455  19.510909  19.510909
# 2010-09-30  20.779048  21.276190  20.309048  20.740476  20.740476
# 2010-10-31  20.723333  20.992857  20.425714  20.713333  20.713333
#
#                   Volume
# Date
# 2010-06-30  1.797670e+07
# 2010-07-31  3.075038e+06
# 2010-08-31  6.835545e+05
# 2010-09-30  8.593286e+05
# 2010-10-31  3.118000e+05

# %%
down.resample('D').mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-30   22.395001   27.710000   20.420000   23.860000   23.860000
# 2010-07-01         NaN         NaN         NaN         NaN         NaN
# 2010-07-02         NaN         NaN         NaN         NaN         NaN
# 2010-07-03         NaN         NaN         NaN         NaN         NaN
# 2010-07-04         NaN         NaN         NaN         NaN         NaN
# 2010-07-05         NaN         NaN         NaN         NaN         NaN
# 2010-07-06         NaN         NaN         NaN         NaN         NaN
# 2010-07-07         NaN         NaN         NaN         NaN         NaN
# 2010-07-08         NaN         NaN         NaN         NaN         NaN
# 2010-07-09         NaN         NaN         NaN         NaN         NaN
# 2010-07-10         NaN         NaN         NaN         NaN         NaN
# 2010-07-11         NaN         NaN         NaN         NaN         NaN
# ...

# %%
import pytz

# %%
len(pytz.all_timezones)
# Out:
# 591

# %%
pytz.all_timezones[:10]
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau']

# %%
import re # regex

# %%
regex = re.compile(r'^US')
list(filter(regex.search, pytz.common_timezones))
# Out:
# ['US/Alaska',
#  'US/Arizona',
#  'US/Central',
#  'US/Eastern',
#  'US/Hawaii',
#  'US/Mountain',
#  'US/Pacific']

# %%
depart = pd.Timestamp('2018-10-19 18:35', tz='US/Eastern')
depart
# Out:
# Timestamp('2018-10-19 20:00:00-0400', tz='US/Eastern')

# %%
arrive = pd.Timestamp('2018-10-20 01:00', tz='US/Pacific')

# %%
a = arrive.tz_convert('US/Eastern')

# %%
a
# Out:
# Timestamp('2018-10-20 04:00:00-0400', tz='US/Eastern')

# %%
t = a - depart

# %%
# time delta to an actual number

# %%
t.days
# Out:
# 0
